# %% [markdown]
# # Time Series Decomposition

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ### Read AirPassengers data

# %%
import pandas as pd
df = pd.read_csv('AirPassengers.csv')
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df.columns = ['Month','nPass']
df.head()
# Out:
#      Month  nPass
# 0  1949-01    112
# 1  1949-02    118
# 2  1949-03    132
# 3  1949-04    129
# 4  1949-05    121

# %% [markdown]
# ### Convert month column to datetime

# %%
df['Month'] = pd.to_datetime(df['Month'])
df.head()
# Out:
#        Month  nPass
# 0 1949-01-01    112
# 1 1949-02-01    118
# 2 1949-03-01    132
# 3 1949-04-01    129
# 4 1949-05-01    121

# %%
df.dtypes
# Out:
# Month    datetime64[ns]
# nPass             int64
# dtype: object

# %%
df.index = df['Month']

# %%
df
# Out:
#                 Month  nPass
# Month
# 1949-01-01 1949-01-01    112
# 1949-02-01 1949-02-01    118
# 1949-03-01 1949-03-01    132
# 1949-04-01 1949-04-01    129
# 1949-05-01 1949-05-01    121
# ...               ...    ...
# 1960-08-01 1960-08-01    606
# 1960-09-01 1960-09-01    508
# 1960-10-01 1960-10-01    461
# 1960-11-01 1960-11-01    390
# 1960-12-01 1960-12-01    432
#
# [144 rows x 2 columns]

# %% [markdown]
# ### Drop Month columns

# %%
df = df.drop(columns=['Month'])
df.head()
# Out:
#             nPass
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %% [markdown]
# ### Visualize the time series data

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(df['nPass'])
plt.title('Time Series data for AirPassengers')
plt.xlabel('Date')
plt.ylabel('No. of Passengers')
plt.show()

# %% [markdown]
# ### Time Series decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
T = seasonal_decompose(df['nPass'], model='multiplicative')

# %%
T.plot()

# %%
T.trend.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
T.seasonal.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
T.resid.plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ### Time Series forecasting

# %% [markdown]
# ### Install pmdarima library

# %%
# %pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp311-cp311-win_amd64.whl (566 kB)
#      ---------------------------------------- 0.0/566.2 kB ? eta -:--:--
#      ---------------- --------------------- 245.8/566.2 kB 7.4 MB/s eta 0:00:01
#      ------------------------------------  563.2/566.2 kB 11.8 MB/s eta 0:00:01
#      ------------------------------------  563.2/566.2 kB 11.8 MB/s eta 0:00:01
#      -------------------------------------- 566.2/566.2 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in e:\advancedpython\repository\venv\lib\site-packages (from pmdarima) (1.3.2)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Obtaining dependency information for Cython!=0.29.18,!=0.29.31,>=0.29 from https://files.pythonhosted.org/packages/39/5d/5ae976df4e368327864917a24f9dee7c8176de1b5b7044ee9903b8adb07a/Cython-3.0.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading Cython-3.0.3-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.2 in e:\advancedpython\repository\venv\lib\site-packages (from pmdarima) (1.25.2)
# Requirement already satisfied: pandas>=0.19 in e:\advancedpython\repository\venv\lib\site-packages (from pmdarima) (2.1.0)
# Requirement already satisfied: scikit-learn>=0.22 in e:\advancedpython\repository\venv\lib\site-packages (from pmdarima) (1.3.0)
# Requirement already satisfied: scipy>=1.3.2 in e:\advancedpython\repository\venv\lib\site-packages (from pmdarima) (1.11.2)
# Requirement already satisfied: statsmodels>=0.13.2 in e:\advancedpython\repository\venv\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in e:\advancedpython\repository\venv\lib\site-packages (from pmdarima) (2.0.6)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in e:\advancedpython\repository\venv\lib\site-packages (from pmdarima) (65.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\advancedpython\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\advancedpython\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\advancedpython\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\advancedpython\repository\venv\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in e:\advancedpython\repository\venv\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in e:\advancedpython\repository\venv\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (23.1)
# Requirement already satisfied: six in e:\advancedpython\repository\venv\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading Cython-3.0.3-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/2.8 MB 14.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.9/2.8 MB 14.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.4/2.8 MB 12.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.8 MB 12.7 MB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 2.7/2.8 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 6.6 MB/s eta 0:00:00
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.0.3 pmdarima-2.0.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Restart and run all cells

# %%
from pmdarima import auto_arima

# %%
model = auto_arima(df['nPass'], seasonal=True, m=12)

# %%
model.order
# Out:
# (2, 1, 1)

# %% [markdown]
# ### Model selected is ARMIA(p=2, d=1, q=1)

# %%
forecast, conf_interval = model.predict(n_periods=36, return_conf_int=True)

# %%
forecast
# Out:
# 1961-01-01    445.634907
# 1961-02-01    420.394942
# 1961-03-01    449.198225
# 1961-04-01    491.839807
# 1961-05-01    503.394291
# 1961-06-01    566.862218
# 1961-07-01    654.259899
# 1961-08-01    638.597167
# 1961-09-01    540.883380
# 1961-10-01    494.126221
# 1961-11-01    423.332274
# 1961-12-01    465.507108
# 1962-01-01    479.290363
# 1962-02-01    454.176270
# 1962-03-01    483.086356
# 1962-04-01    525.818559
# 1962-05-01    537.449936
# 1962-06-01    600.983107
# 1962-07-01    688.436146
# 1962-08-01    672.820386
# 1962-09-01    575.146455
# 1962-10-01    528.423113
# 1962-11-01    457.657860
# 1962-12-01    499.857041
# 1963-01-01    513.660954
# 1963-02-01    488.564390
# 1963-03-01    517.489348
# 1963-04-01    560.234172
# 1963-05-01    571.876256
# 1963-06-01    635.418512
# 1963-07-01    722.879260
# 1963-08-01    707.270042
# 1963-09-01    609.601660
# 1963-10-01    562.883028
# 1963-11-01    492.121771
# 1963-12-01    534.324343
# Freq: MS, dtype: float64

# %%
forecast = forecast.apply(round)

# %%
forecast
# Out:
# 1961-01-01    446
# 1961-02-01    420
# 1961-03-01    449
# 1961-04-01    492
# 1961-05-01    503
# 1961-06-01    567
# 1961-07-01    654
# 1961-08-01    639
# 1961-09-01    541
# 1961-10-01    494
# 1961-11-01    423
# 1961-12-01    466
# 1962-01-01    479
# 1962-02-01    454
# 1962-03-01    483
# 1962-04-01    526
# 1962-05-01    537
# 1962-06-01    601
# 1962-07-01    688
# 1962-08-01    673
# 1962-09-01    575
# 1962-10-01    528
# 1962-11-01    458
# 1962-12-01    500
# 1963-01-01    514
# 1963-02-01    489
# 1963-03-01    517
# 1963-04-01    560
# 1963-05-01    572
# 1963-06-01    635
# 1963-07-01    723
# 1963-08-01    707
# 1963-09-01    610
# 1963-10-01    563
# 1963-11-01    492
# 1963-12-01    534
# Freq: MS, dtype: int64

# %%
conf_interval
# Out:
# array([[423.34488264, 467.92493165],
#        [394.23564894, 446.55423507],
#        [419.83210771, 478.56434165],
#        [460.37679811, 523.30281527],
#        [470.38111403, 536.40746738],
#        [532.70008828, 601.02434825],
#        [619.22199213, 689.29780492],
#        [602.88077613, 674.31355781],
#        [504.63222253, 577.13453725],
#        [457.44691601, 530.80552559],
#        [386.30486083, 460.35968637],
#        [428.19237042, 502.82184652],
#        [433.49861559, 525.08211028],
#        [405.11019165, 503.24234886],
#        [431.15712965, 535.01558147],
#        [471.84221792, 579.79490098],
#        [481.8754046 , 593.02446742],
#        [544.15855734, 657.80765626],
#        [630.61085546, 746.26143624],
#        [614.18136964, 731.45940267],
#        [515.83469612, 634.45821315],
#        [468.54648192, 588.29974394],
#        [397.29971635, 518.01600314],
#        [439.08245577, 560.63162711],
#        [446.32983564, 580.99207268],
#        [418.32114752, 558.80763244],
#        [444.62739371, 590.35130268],
#        [485.40521297, 635.06313049],
#        [495.45403686, 648.29847522],
#        [557.70269665, 713.13432802],
#        [644.09058068, 801.66794019],
#        [627.57822473, 786.96185897],
#        [529.13756636, 690.06575456],
#        [481.74887918, 644.01717687],
#        [410.39811238, 573.84542893],
#        [452.07520634, 616.57347925]])

# %%
lower = conf_interval[:,0]
upper = conf_interval[:,1]

# %%
upper
# Out:
# array([467.92493165, 446.55423507, 478.56434165, 523.30281527,
#        536.40746738, 601.02434825, 689.29780492, 674.31355781,
#        577.13453725, 530.80552559, 460.35968637, 502.82184652,
#        525.08211028, 503.24234886, 535.01558147, 579.79490098,
#        593.02446742, 657.80765626, 746.26143624, 731.45940267,
#        634.45821315, 588.29974394, 518.01600314, 560.63162711,
#        580.99207268, 558.80763244, 590.35130268, 635.06313049,
#        648.29847522, 713.13432802, 801.66794019, 786.96185897,
#        690.06575456, 644.01717687, 573.84542893, 616.57347925])

# %%
lower
# Out:
# array([423.34488264, 394.23564894, 419.83210771, 460.37679811,
#        470.38111403, 532.70008828, 619.22199213, 602.88077613,
#        504.63222253, 457.44691601, 386.30486083, 428.19237042,
#        433.49861559, 405.11019165, 431.15712965, 471.84221792,
#        481.8754046 , 544.15855734, 630.61085546, 614.18136964,
#        515.83469612, 468.54648192, 397.29971635, 439.08245577,
#        446.32983564, 418.32114752, 444.62739371, 485.40521297,
#        495.45403686, 557.70269665, 644.09058068, 627.57822473,
#        529.13756636, 481.74887918, 410.39811238, 452.07520634])

# %% [markdown]
# ### Plot the forecast along with orignal data

# %%
plt.figure(figsize=(16,8))
plt.plot(df['nPass'], label='Orignal')
plt.plot(forecast, label='forecast')
plt.fill_between(forecast.index, lower, upper, alpha=0.5, color='gray', label='confidence interval')
plt.show()

# %% [markdown]
# ### Save forecasted data into dataframe

# %%
df_pred = forecast.to_frame()
df_pred
# Out:
#               0
# 1961-01-01  446
# 1961-02-01  420
# 1961-03-01  449
# 1961-04-01  492
# 1961-05-01  503
# 1961-06-01  567
# 1961-07-01  654
# 1961-08-01  639
# 1961-09-01  541
# 1961-10-01  494
# 1961-11-01  423
# 1961-12-01  466
# 1962-01-01  479
# 1962-02-01  454
# 1962-03-01  483
# 1962-04-01  526
# 1962-05-01  537
# 1962-06-01  601
# 1962-07-01  688
# 1962-08-01  673
# 1962-09-01  575
# 1962-10-01  528
# 1962-11-01  458
# 1962-12-01  500
# 1963-01-01  514
# 1963-02-01  489
# 1963-03-01  517
# 1963-04-01  560
# 1963-05-01  572
# 1963-06-01  635
# 1963-07-01  723
# 1963-08-01  707
# 1963-09-01  610
# 1963-10-01  563
# 1963-11-01  492
# 1963-12-01  534

# %%
df_pred.columns = ['Forecast']

# %%
df_pred
# Out:
#             Forecast
# 1961-01-01       446
# 1961-02-01       420
# 1961-03-01       449
# 1961-04-01       492
# 1961-05-01       503
# 1961-06-01       567
# 1961-07-01       654
# 1961-08-01       639
# 1961-09-01       541
# 1961-10-01       494
# 1961-11-01       423
# 1961-12-01       466
# 1962-01-01       479
# 1962-02-01       454
# 1962-03-01       483
# 1962-04-01       526
# 1962-05-01       537
# 1962-06-01       601
# 1962-07-01       688
# 1962-08-01       673
# 1962-09-01       575
# 1962-10-01       528
# 1962-11-01       458
# 1962-12-01       500
# 1963-01-01       514
# 1963-02-01       489
# 1963-03-01       517
# 1963-04-01       560
# 1963-05-01       572
# 1963-06-01       635
# 1963-07-01       723
# 1963-08-01       707
# 1963-09-01       610
# 1963-10-01       563
# 1963-11-01       492
# 1963-12-01       534

# %%
df_pred['lower'] = lower
df_pred['upper'] = upper

# %%
df_pred
# Out:
#             Forecast       lower       upper
# 1961-01-01       446  423.344883  467.924932
# 1961-02-01       420  394.235649  446.554235
# 1961-03-01       449  419.832108  478.564342
# 1961-04-01       492  460.376798  523.302815
# 1961-05-01       503  470.381114  536.407467
# 1961-06-01       567  532.700088  601.024348
# 1961-07-01       654  619.221992  689.297805
# 1961-08-01       639  602.880776  674.313558
# 1961-09-01       541  504.632223  577.134537
# 1961-10-01       494  457.446916  530.805526
# 1961-11-01       423  386.304861  460.359686
# 1961-12-01       466  428.192370  502.821847
# 1962-01-01       479  433.498616  525.082110
# 1962-02-01       454  405.110192  503.242349
# 1962-03-01       483  431.157130  535.015581
# 1962-04-01       526  471.842218  579.794901
# 1962-05-01       537  481.875405  593.024467
# 1962-06-01       601  544.158557  657.807656
# 1962-07-01       688  630.610855  746.261436
# 1962-08-01       673  614.181370  731.459403
# 1962-09-01       575  515.834696  634.458213
# 1962-10-01       528  468.546482  588.299744
# 1962-11-01       458  397.299716  518.016003
# 1962-12-01       500  439.082456  560.631627
# 1963-01-01       514  446.329836  580.992073
# 1963-02-01       489  418.321148  558.807632
# 1963-03-01       517  444.627394  590.351303
# 1963-04-01       560  485.405213  635.063130
# 1963-05-01       572  495.454037  648.298475
# 1963-06-01       635  557.702697  713.134328
# 1963-07-01       723  644.090581  801.667940
# 1963-08-01       707  627.578225  786.961859
# 1963-09-01       610  529.137566  690.065755
# 1963-10-01       563  481.748879  644.017177
# 1963-11-01       492  410.398112  573.845429
# 1963-12-01       534  452.075206  616.573479

# %%
df_pred['lower'] = df_pred['lower'].apply(round)
df_pred['upper'] = df_pred['upper'].apply(round)

# %%
df_pred
# Out:
#             Forecast  lower  upper
# 1961-01-01       446    423    468
# 1961-02-01       420    394    447
# 1961-03-01       449    420    479
# 1961-04-01       492    460    523
# 1961-05-01       503    470    536
# 1961-06-01       567    533    601
# 1961-07-01       654    619    689
# 1961-08-01       639    603    674
# 1961-09-01       541    505    577
# 1961-10-01       494    457    531
# 1961-11-01       423    386    460
# 1961-12-01       466    428    503
# 1962-01-01       479    433    525
# 1962-02-01       454    405    503
# 1962-03-01       483    431    535
# 1962-04-01       526    472    580
# 1962-05-01       537    482    593
# 1962-06-01       601    544    658
# 1962-07-01       688    631    746
# 1962-08-01       673    614    731
# 1962-09-01       575    516    634
# 1962-10-01       528    469    588
# 1962-11-01       458    397    518
# 1962-12-01       500    439    561
# 1963-01-01       514    446    581
# 1963-02-01       489    418    559
# 1963-03-01       517    445    590
# 1963-04-01       560    485    635
# 1963-05-01       572    495    648
# 1963-06-01       635    558    713
# 1963-07-01       723    644    802
# 1963-08-01       707    628    787
# 1963-09-01       610    529    690
# 1963-10-01       563    482    644
# 1963-11-01       492    410    574
# 1963-12-01       534    452    617

# %% [markdown]
# ### Save predictions to csv

# %%
df_pred.to_csv('Predictions.csv')
